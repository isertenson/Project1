# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b>Nguyen Thi Huyen Tran</b><br>
#     Data Scientist

# %% [markdown]
# <i>I am interested in data science because it is the sexiest job of century</i>

# %% [markdown]
# <h3>My code is used for calculating<h3>

# %%
1+1
# Out:
# 2

# %% [markdown]
# - This is a bullet list
# - This is a bullet list
# - This is a bullet list
# ![image](https://burst.shopifycdn.com/photos/two-customized-cars-rolling-through-a-city-street.jpg?width=1200&format=pjpg&exif=0&iptc=0)
